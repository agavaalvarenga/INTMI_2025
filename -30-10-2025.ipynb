# %% [markdown]
# <a href="https://colab.research.google.com/github/agavaalvarenga/INTMI_2025/blob/main/-30-10-2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade=int(input("digite sua idade"))
if idade >= 18:
      print("adulto")
elif idade>= 14:
      print("junior")
else:
      print("infantil")
# Out:
# digite sua idade15
# junior

# %%
nome=str(input('digite o seu nome'))
if 'k' in nome:
  print('o nome tem a letra k')
else:
  print('o nome não tem a letra k')
# Out:
# digite o seu nomeana
# o nome não tem a letra k

# %%
numero = float(input("Digite um número: "))

if numero > 10:
    print("O número é maior que 10.")
else:
    print("O número não é maior que 10.")
# Out:
# Digite um número: 6
# O número não é maior que 10.

# %%
numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0:
    print("O número é par.")
else:
    print("O número é ímpar.")
# Out:
# Digite um número inteiro: 6
# O número é par.

# %%
nome = input("Digite um nome: ")

if "a" in nome.lower():
    print("O nome contém a letra 'a'.")
else:
    print("O nome não contém a letra 'a'.")
# Out:
# Digite um nome: ester
# O nome não contém a letra 'a'.

# %%
numero = float(input("Digite um número: "))

if numero % 5 == 0:
    print("O número é múltiplo de 5.")
else:
    print("O número não é múltiplo de 5.")
# Out:
# Digite um número:  2
# O número não é múltiplo de 5.

# %%
temperatura = float(input("Digite a temperatura atual em °C: "))

if temperatura > 30:
    print("Está quente!")
else:
    print("Está frio!")
# Out:
# Digite a temperatura atual em °C: 26
# Está frio!

# %%
resposta = input('Digite "S" para continuar ou "N" para sair: ').strip().upper()

if resposta == "S":
    print("Você escolheu continuar.")
elif resposta == "N":
    print("Você escolheu sair.")
else:
    print("Opção inválida. Digite apenas 'S' ou 'N'.")
# Out:
# Digite "S" para continuar ou "N" para sair: s
# Você escolheu continuar.

# %%
numero = float(input("Digite um número: "))

if numero < 0:
    print("O número é negativo.")
elif numero == 0:
    print("O número é zero.")
else:
    print("O número é positivo.")
# Out:
# Digite um número: 6
# O número é positivo.

# %%
numero = int(input("Digite um número de 1 a 7: "))

if numero == 1:
    print("Domingo")
elif numero == 2:
    print("Segunda-feira")
elif numero == 3:
    print("Terça-feira")
elif numero == 4:
    print("Quarta-feira")
elif numero == 5:
    print("Quinta-feira")
elif numero == 6:
    print("Sexta-feira")
elif numero == 7:
    print("Sábado")
else:
    print("Número inválido! Digite um valor entre 1 e 7.")
# Out:
# Digite um número de 1 a 7: 6
# Sexta-feira

# %%
ano = int(input("Digite um ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print("O ano é bissexto.")
else:
    print("O ano não é bissexto.")
# Out:
# Digite um ano: 2
# O ano não é bissexto.

# %%
horas = float(input("Digite a quantidade de horas trabalhadas: "))
valor_hora = float(input("Digite o valor da hora: R$ "))

if horas <= 40:
    salario = horas * valor_hora
else:
    horas_extras = horas - 40
    salario = (40 * valor_hora) + (horas_extras * valor_hora * 1.5)

print(f"O salário a receber é: R$ {salario:.2f}")
# Out:
# Digite a quantidade de horas trabalhadas: 7
# Digite o valor da hora: R$ 5
# O salário a receber é: R$ 35.00
